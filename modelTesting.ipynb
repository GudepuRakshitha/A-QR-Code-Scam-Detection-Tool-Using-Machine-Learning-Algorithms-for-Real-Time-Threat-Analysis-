# %%
# import cv2
# from pyzbar.pyzbar import decode

# def scan_and_draw_qr_codes(image_path, output_path="output.png"):
#     # Read the image
#     image = cv2.imread(image_path)

#     # Decode all QR codes
#     qr_codes = decode(image)

#     if not qr_codes:
#         print("No QR codes found in the image.")
#         return []

#     extracted_data = []

#     for i, qr in enumerate(qr_codes):
#         data = qr.data.decode('utf-8')
#         extracted_data.append(data)
#         print(f"[QR {i+1}] Extracted Data: {data}")

#         # Get the bounding box coordinates
#         pts = qr.polygon
#         if len(pts) == 4:
#             pts = [(pt.x, pt.y) for pt in pts]
#             for j in range(4):
#                 cv2.line(image, pts[j], pts[(j+1)%4], (0, 255, 0), 3)

#         # Optionally put the index or data above the QR
#         x, y = pts[0]
#         cv2.putText(image, f"QR {i+1}", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 
#                     0.6, (0, 255, 0), 2)

#     # Save the image with boxes
#     cv2.imwrite(output_path, image)
#     print(f"\nSaved image with boxes to: {output_path}")
    
#     return extracted_data

# # Example usage
# scan_and_draw_qr_codes("sample_multi_qr.png")

# %%
# import requests

# # API_KEY = "AIzaSyCUj_bA0bwgtrut-Y5sC71efFxZKJ6f4s4"

# # def check_google_safe_browsing(url):
# #     endpoint = f"https://safebrowsing.googleapis.com/v4/threatMatches:find?key={API_KEY}"
# #     payload = {
# #         "client": {"clientId": "QRScanner", "clientVersion": "1.0"},
# #         "threatInfo": {
# #             "threatTypes": ["MALWARE", "SOCIAL_ENGINEERING"],
# #             "platformTypes": ["ANY_PLATFORM"],
# #             "threatEntryTypes": ["URL"],
# #             "threatEntries": [{"url": url}]
# #         }
# #     }
    
# #     response = requests.post(endpoint, json=payload)
# #     return response.json()

# # # Example usage
# # print(check_google_safe_browsing(scan_qr_code("testimage.jpg")))

# %%
# import cv2
# from pyzbar.pyzbar import decode

# def scan_qr_code(image_path):
#     # Read the image
#     image = cv2.imread(image_path)
    
#     # Decode the QR codes in the image
#     qr_codes = decode(image)

#     # Check if any QR code is found
#     if not qr_codes:
#         print("No QR code found in the image.")
#         return None

#     for qr in qr_codes:
#         url = qr.data.decode('utf-8')  # Extract text (URL or data)
#         print("Extracted Data:", url)
#         return url  # Return first QR code data found

#     return None

# # Example usage
# image_path = "testimage.jpg"  # Change this to your QR code image
# scan_qr_code(image_path)

# %%
import qrcode

fake_url = "http://secure-login-paypal-support-alert.xyz"

qr = qrcode.make(fake_url)
qr.save("fake_malicious_qr.png")
print("Fake malicious QR code saved as 'fake_malicious_qr.png'")
# Out:
# Fake malicious QR code saved as 'fake_malicious_qr.png'

# %%
import cv2
from pyzbar.pyzbar import decode

def scan_qr_codes(image_path):
    # Read the image
    image = cv2.imread(image_path)

    # Decode all QR codes in the image
    qr_codes = decode(image)

    # If none found
    if not qr_codes:
        print("No QR codes found in the image.")
        return []

    # Extract and print each QR code's data
    extracted_data = []
    for i, qr in enumerate(qr_codes):
        data = qr.data.decode('utf-8')
        print(f"[QR {i+1}] Extracted Data: {data}")
        extracted_data.append(data)

    return extracted_data

# Example usage
image_path = "testimage.jpg"  # Change this to your QR image file
scan_qr_codes(image_path)
# Out:
# [QR 1] Extracted Data: https://www.meetup.com/technexus-community/events/306934878/
# ['https://www.meetup.com/technexus-community/events/306934878/']

# %%
import requests

API_KEY = "AIzaSyCUj_bA0bwgtrut-Y5sC71efFxZKJ6f4s4"  # replace with your key

def check_url_with_google_safe_browsing(url):
    endpoint = f"https://safebrowsing.googleapis.com/v4/threatMatches:find?key={API_KEY}"
    payload = {
        "client": {"clientId": "qrscanner", "clientVersion": "1.0"},
        "threatInfo": {
            "threatTypes": ["MALWARE", "SOCIAL_ENGINEERING", "UNWANTED_SOFTWARE"],
            "platformTypes": ["ANY_PLATFORM"],
            "threatEntryTypes": ["URL"],
            "threatEntries": [{"url": url}]
        }
    }

    response = requests.post(endpoint, json=payload)
    result = response.json()

    if result.get("matches"):
        return "MALICIOUS"
    else:
        return "SAFE"

# %%
import whois
from datetime import datetime

def get_domain_age(url):
    try:
        # Extract domain (strip protocol and path)
        domain = url.split("//")[-1].split("/")[0]
        w = whois.whois(domain)

        creation_date = w.creation_date

        # Some domains return a list of creation dates
        if isinstance(creation_date, list):
            creation_date = creation_date[0]

        if creation_date is None:
            return "Unknown (No creation date found)"

        age_days = (datetime.now() - creation_date).days

        if age_days < 180:
            return f"New Domain ({age_days} days old)"
        else:
            return f"Established Domain ({age_days} days old)"
    except Exception as e:
        print("WHOIS Lookup Failed:", e)
        return "WHOIS Error"

# %%
import cv2
from pyzbar.pyzbar import decode
import requests

API_KEY = "AIzaSyCUj_bA0bwgtrut-Y5sC71efFxZKJ6f4s4"  # Replace with your key

def scan_qr_codes(image_path):
    image = cv2.imread(image_path)
    qr_codes = decode(image)

    if not qr_codes:
        print("No QR codes found.")
        return []

    extracted_data = []
    for i, qr in enumerate(qr_codes):
        data = qr.data.decode('utf-8')
        print(f"\n[QR {i+1}] Data: {data}")

        status = check_url_with_google_safe_browsing(data)
        age_info = get_domain_age(data)

        print(f"    → Safety: {status}")
        print(f"    → Domain Age: {age_info}")

        extracted_data.append((data, status, age_info))


    return extracted_data

def check_url_with_google_safe_browsing(url):
    endpoint = f"https://safebrowsing.googleapis.com/v4/threatMatches:find?key={API_KEY}"
    payload = {
        "client": {"clientId": "qrscanner", "clientVersion": "1.0"},
        "threatInfo": {
            "threatTypes": ["MALWARE", "SOCIAL_ENGINEERING", "UNWANTED_SOFTWARE"],
            "platformTypes": ["ANY_PLATFORM"],
            "threatEntryTypes": ["URL"],
            "threatEntries": [{"url": url}]
        }
    }

    try:
        response = requests.post(endpoint, json=payload)
        result = response.json()
        if result.get("matches"):
            return "MALICIOUS"
        else:
            return "SAFE"
    except Exception as e:
        print("Error checking URL:", e)
        return "ERROR"

# Example usage
image_path = "testimage7.png"
scan_qr_codes(image_path)
# Out:
# [QR 1] Data: 316254    http://atualizacaodedados.online
# Name: url, dtype: object
#     → Safety: SAFE
#     → Domain Age: Unknown (No creation date found)
# [('316254    http://atualizacaodedados.online\nName: url, dtype: object',
#   'SAFE',
#   'Unknown (No creation date found)')]

# %%
import cv2
from pyzbar.pyzbar import decode
import requests
import whois
from datetime import datetime
import csv
import json

API_KEY = "AIzaSyCUj_bA0bwgtrut-Y5sC71efFxZKJ6f4s4"

def scan_qr_codes(image_path):
    image = cv2.imread(image_path)
    qr_codes = decode(image)

    if not qr_codes:
        print("No QR codes found.")
        return []

    extracted_data = []
    for i, qr in enumerate(qr_codes):
        data = qr.data.decode('utf-8')
        print(f"\n[QR {i+1}] Data: {data}")

        status = check_url_with_google_safe_browsing(data)
        age_info = get_domain_age(data)

        print(f"    → Safety: {status}")
        print(f"    → Domain Age: {age_info}")

        extracted_data.append((data, status, age_info))

    return extracted_data

def check_url_with_google_safe_browsing(url):
    endpoint = f"https://safebrowsing.googleapis.com/v4/threatMatches:find?key={API_KEY}"
    payload = {
        "client": {"clientId": "qrscanner", "clientVersion": "1.0"},
        "threatInfo": {
            "threatTypes": ["MALWARE", "SOCIAL_ENGINEERING", "UNWANTED_SOFTWARE"],
            "platformTypes": ["ANY_PLATFORM"],
            "threatEntryTypes": ["URL"],
            "threatEntries": [{"url": url}]
        }
    }

    try:
        response = requests.post(endpoint, json=payload)
        result = response.json()
        if result.get("matches"):
            return "MALICIOUS"
        else:
            return "SAFE"
    except Exception as e:
        print("Error checking URL:", e)
        return "ERROR"

def get_domain_age(url):
    try:
        domain = url.split("//")[-1].split("/")[0]
        w = whois.whois(domain)
        creation_date = w.creation_date

        if isinstance(creation_date, list):
            creation_date = creation_date[0]

        if creation_date is None:
            return "Unknown (no creation date found)"

        age_days = (datetime.now() - creation_date).days

        if age_days < 180:
            return f"New Domain ({age_days} days old)"
        else:
            return f"Established Domain ({age_days} days old)"
    except Exception as e:
        print("WHOIS Lookup Failed:", e)
        return "WHOIS Error"

def export_to_csv(results, filename="qr_scan_results.csv"):
    with open(filename, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["QR Data", "Safety", "Domain Age"])
        for row in results:
            writer.writerow(row)
    print(f"\nResults exported to {filename}")

def export_to_json(results, filename="qr_scan_results.json"):
    data = [
        {"qr_data": r[0], "safety": r[1], "domain_age": r[2]}
        for r in results
    ]
    with open(filename, mode='w', encoding='utf-8') as f:
        json.dump(data, f, indent=4)
    print(f"Results exported to {filename}")

if __name__ == "__main__":
    image_path = "testimage7.png"
    results = scan_qr_codes(image_path)

    if results:
        export_to_csv(results)
        export_to_json(results)
# Out:
# [QR 1] Data: 316254    http://atualizacaodedados.online
# Name: url, dtype: object
#     → Safety: SAFE
#     → Domain Age: Unknown (no creation date found)
#
# Results exported to qr_scan_results.csv
# Results exported to qr_scan_results.json
